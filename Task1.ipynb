# %% [markdown]
# <a href="https://colab.research.google.com/github/Faizan-d1/CODSOFT/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Faizan-d1/CODSOFT.git
# %cd CODSOFT
# !ls
# Out:
# Cloning into 'CODSOFT'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 28 (delta 2), reused 7 (delta 2), pack-reused 20 (from 1)
# Receiving objects: 100% (28/28), 27.87 MiB | 10.69 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# /content/CODSOFT
# Task1_Movie_Genre_Classification  Task3_Customer_Churn_Prediction
# Task2_Creditcard_Fraud_Detection  Task4_Spam_SMS_Detection

# %%
# %cd Task1_Movie_Genre_Classification
# !ls
# Out:
# /content/CODSOFT/Task1_Movie_Genre_Classification
# movie_genre_classifier.py  test_data_solution.txt  train_data.txt
# README.md		   test_data.txt

# %%
# !pip install numpy pandas matplotlib seaborn scikit-learn

# %%
# %run movie_genre_classifier.py
# Out:
# 📊 Dataset Loaded
# Total samples: 54214
# Unique genres: 27
#       genre                                        description
# 0     drama  Listening in to a conversation between his doc...
# 1  thriller  A brother and sister with a past incestuous re...
# 2     adult  As the bus empties the students for their fiel...
# 3     drama  To help their unemployed father make ends meet...
# 4     drama  The film's title refers not only to the un-rec...
#
# Training samples: 43371
# Testing samples: 10843
#
# ✅ Model Accuracy: 0.5704
#
# 📊 Classification Report:
#
#               precision    recall  f1-score   support
#
#       action       0.43      0.32      0.37       263
#        adult       0.59      0.41      0.48       112
#    adventure       0.31      0.22      0.25       139
#    animation       0.35      0.18      0.24       104
#    biography       0.00      0.00      0.00        61
#       comedy       0.51      0.56      0.54      1443
# ...

# %%
# !pip install jupytext
# !jupytext --to notebook movie_genre_classifier.py
# Out:
# ...
# [jupytext] Reading movie_genre_classifier.py in format py
# [jupytext] Writing movie_genre_classifier.ipynb
